# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
from scipy.ndimage import convolve
from sklearn import linear_model, datasets, metrics
from sklearn.model_selection import train_test_split
from sklearn.neural_network import BernoulliRBM
from sklearn import preprocessing
from sklearn.model_selection import GridSearchCV, cross_val_score
from sklearn.metrics import classification_report
from sklearn.pipeline import Pipeline
from sklearn import ensemble

# %%
train = pd.read_csv('sign_mnist_train.csv')
test = pd.read_csv('sign_mnist_test.csv')

# %%
train.head()
# Out:
#    label  pixel1  pixel2  pixel3  pixel4  pixel5  pixel6  pixel7  pixel8  \
# 0      3     107     118     127     134     139     143     146     150
# 1      6     155     157     156     156     156     157     156     158
# 2      2     187     188     188     187     187     186     187     188
# 3      2     211     211     212     212     211     210     211     210
# 4     13     164     167     170     172     176     179     180     184
#
#    pixel9    ...     pixel775  pixel776  pixel777  pixel778  pixel779  \
# 0     153    ...          207       207       207       207       206
# 1     158    ...           69       149       128        87        94
# 2     187    ...          202       201       200       199       198
# 3     210    ...          235       234       233       231       230
# 4     185    ...           92       105       105       108       133
#
#    pixel780  pixel781  pixel782  pixel783  pixel784
# 0       206       206       204       203       202
# 1       163       175       103       135       149
# 2       199       198       195       194       195
# 3       226       225       222       229       163
# 4       163       157       163       164       179
#
# [5 rows x 785 columns]

# %%
# Split into X & Y sets 
X_train = train.drop('label', axis=1)
Y_train = train['label']
X_test = test.drop('label', axis=1)
Y_test = test['label']

# %%
z = X_train.iloc[1]
im1 = np.array(z)

# %%
plt.figure(figsize=(16, 16))
for i in np.arange(100):
    plt.subplot(10, 10, i + 1)
    z = X_train.iloc[i]
    zz = np.array(z)
    image = zz.reshape((28,28))
    plt.imshow(image)
    plt.xticks(())
    plt.yticks(())
plt.suptitle('100 Images', fontsize=16)

plt.show()

# %%
X_train = (X_train - np.min(X_train, 0)) / (np.max(X_train, 0) + 0.0001)  # 0-1 scaling

# %%
# Training Logistic regression
logistic_classifier = linear_model.LogisticRegression(C=100.0)
logistic_classifier.fit(X_train, Y_train)
# Out:
# LogisticRegression(C=100.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='ovr', n_jobs=1,
#           penalty='l2', random_state=None, solver='liblinear', tol=0.0001,
#           verbose=0, warm_start=False)

# %%
print("Logistic regression using raw pixel features:\n%s\n" % (
    metrics.classification_report(
        Y_test,
        logistic_classifier.predict(X_test))))
# Out:
# Logistic regression using raw pixel features:
#              precision    recall  f1-score   support
#
#           0       0.82      0.88      0.85       331
#           1       1.00      0.81      0.90       432
#           2       0.93      0.86      0.89       310
#           3       0.66      1.00      0.79       245
#           4       0.76      0.92      0.83       498
#           5       0.49      0.83      0.61       247
#           6       0.68      0.75      0.71       348
#           7       0.94      0.61      0.74       436
#           8       0.54      0.57      0.55       288
#          10       0.61      0.30      0.40       331
#          11       0.80      0.89      0.84       209
#          12       0.64      0.48      0.55       394
#          13       0.52      0.45      0.48       291
#          14       0.97      0.62      0.76       246
#          15       1.00      0.37      0.54       347
#          16       0.33      0.74      0.45       164
#          17       0.19      0.43      0.27       144
#          18       0.36      0.45      0.40       246
#          19       0.38      0.55      0.45       248
#          20       0.54      0.50      0.52       266
#          21       0.52      0.53      0.53       346
#          22       0.38      0.42      0.40       206
#          23       0.67      0.43      0.52       267
#          24       0.65      0.46      0.54       332
#
# avg / total       0.68      0.63      0.63      7172

# %%
logistic_classifier.score(X_test, Y_test)
# Out:
# 0.6261851645287229

# %%
from sklearn.svm import SVC
svc = SVC()
svc.fit(X_train, Y_train)
# Out:
# SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto', kernel='rbf',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False)

# %%
print("SVM using raw pixel features:\n%s\n" % (
    metrics.classification_report(
        Y_test,
        svc.predict(X_test))))
# Out:
# SVM using raw pixel features:
#              precision    recall  f1-score   support
#
#           0       0.00      0.00      0.00       331
#           1       0.00      0.00      0.00       432
#           2       0.00      0.00      0.00       310
#           3       0.00      0.00      0.00       245
#           4       0.00      0.00      0.00       498
#           5       0.00      0.00      0.00       247
#           6       0.00      0.00      0.00       348
#           7       0.00      0.00      0.00       436
#           8       0.00      0.00      0.00       288
#          10       0.00      0.00      0.00       331
#          11       0.00      0.00      0.00       209
#          12       0.00      0.00      0.00       394
#          13       0.00      0.00      0.00       291
#          14       0.03      1.00      0.07       246
#          15       0.00      0.00      0.00       347
#          16       0.00      0.00      0.00       164
#          17       0.00      0.00      0.00       144
#          18       0.00      0.00      0.00       246
#          19       0.00      0.00      0.00       248
#          20       0.00      0.00      0.00       266
#          21       0.00      0.00      0.00       346
#          22       0.00      0.00      0.00       206
#          23       0.00      0.00      0.00       267
#          24       0.00      0.00      0.00       332
#
# avg / total       0.00      0.03      0.00      7172
# /home/brandoncsteed/.local/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)

# %%
svc.score(X_test, Y_test)
# Out:
# 0.034300055772448414

# %%
logistic = linear_model.LogisticRegression(C=100)
rbm = BernoulliRBM(learning_rate=.05, verbose=True)
rbm.fit(X_train)

classifier = Pipeline(steps=[('rbm', rbm), ('logistic', logistic)])
# Out:
# [BernoulliRBM] Iteration 1, pseudo-likelihood = -516.29, time = 17.75s
# [BernoulliRBM] Iteration 2, pseudo-likelihood = -501.90, time = 18.71s
# [BernoulliRBM] Iteration 3, pseudo-likelihood = -497.63, time = 20.32s
# [BernoulliRBM] Iteration 4, pseudo-likelihood = -498.62, time = 18.27s
# [BernoulliRBM] Iteration 5, pseudo-likelihood = -498.65, time = 17.74s
# [BernoulliRBM] Iteration 6, pseudo-likelihood = -494.16, time = 18.08s
# [BernoulliRBM] Iteration 7, pseudo-likelihood = -494.56, time = 18.51s
# [BernoulliRBM] Iteration 8, pseudo-likelihood = -492.41, time = 18.59s
# [BernoulliRBM] Iteration 9, pseudo-likelihood = -496.72, time = 18.86s
# [BernoulliRBM] Iteration 10, pseudo-likelihood = -498.32, time = 18.46s

# %%
# Training RBM-Logistic Pipeline
classifier.fit(X_train, Y_train)
# Out:
# [BernoulliRBM] Iteration 1, pseudo-likelihood = -518.69, time = 18.04s
# [BernoulliRBM] Iteration 2, pseudo-likelihood = -511.62, time = 18.53s
# [BernoulliRBM] Iteration 3, pseudo-likelihood = -502.76, time = 18.36s
# [BernoulliRBM] Iteration 4, pseudo-likelihood = -499.68, time = 18.58s
# [BernoulliRBM] Iteration 5, pseudo-likelihood = -497.41, time = 18.48s
# [BernoulliRBM] Iteration 6, pseudo-likelihood = -494.82, time = 17.98s
# [BernoulliRBM] Iteration 7, pseudo-likelihood = -497.40, time = 18.61s
# [BernoulliRBM] Iteration 8, pseudo-likelihood = -495.97, time = 18.25s
# [BernoulliRBM] Iteration 9, pseudo-likelihood = -504.07, time = 18.80s
# [BernoulliRBM] Iteration 10, pseudo-likelihood = -498.42, time = 19.59s
# Pipeline(memory=None,
#      steps=[('rbm', BernoulliRBM(batch_size=10, learning_rate=0.05, n_components=256, n_iter=10,
#        random_state=None, verbose=True)), ('logistic', LogisticRegression(C=100, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='ovr', n_jobs=1,
#           penalty='l2', random_state=None, solver='liblinear', tol=0.0001,
#           verbose=0, warm_start=False))])

# %%
classifier.score(X_test, Y_test)
# Out:
# 0.19199665365309537

# %%
print("Logistic regression using RBM features:\n%s\n" % (
    metrics.classification_report(
        Y_test,
        classifier.predict(X_test))))
# Out:
# Logistic regression using RBM features:
#              precision    recall  f1-score   support
#
#           0       0.23      0.32      0.27       331
#           1       0.16      0.59      0.25       432
#           2       0.70      0.39      0.50       310
#           3       0.13      0.03      0.05       245
#           4       0.16      0.29      0.21       498
#           5       0.00      0.00      0.00       247
#           6       0.41      0.49      0.45       348
#           7       0.62      0.37      0.46       436
#           8       0.44      0.17      0.25       288
#          10       0.35      0.06      0.11       331
#          11       0.06      0.11      0.08       209
#          12       0.00      0.00      0.00       394
#          13       0.02      0.01      0.01       291
#          14       0.25      0.36      0.30       246
#          15       0.04      0.11      0.06       347
#          16       0.79      0.37      0.51       164
#          17       0.03      0.05      0.04       144
#          18       0.01      0.01      0.01       246
#          19       0.62      0.05      0.10       248
#          20       0.15      0.01      0.02       266
#          21       0.15      0.17      0.16       346
#          22       0.00      0.00      0.00       206
#          23       0.13      0.13      0.13       267
#          24       0.13      0.02      0.03       332
#
# avg / total       0.24      0.19      0.18      7172

# %%
#rfc = ensemble.RandomForestClassifier(n_jobs=-1)
svc_classifier = Pipeline(steps=[('rbm', rbm), ('svc', svc)])
svc_classifier.fit(X_train, Y_train)
# Out:
# [BernoulliRBM] Iteration 1, pseudo-likelihood = -514.34, time = 17.34s
# [BernoulliRBM] Iteration 2, pseudo-likelihood = -510.05, time = 18.31s
# [BernoulliRBM] Iteration 3, pseudo-likelihood = -504.02, time = 18.21s
# [BernoulliRBM] Iteration 4, pseudo-likelihood = -502.24, time = 18.19s
# [BernoulliRBM] Iteration 5, pseudo-likelihood = -495.99, time = 18.17s
# [BernoulliRBM] Iteration 6, pseudo-likelihood = -493.35, time = 19.14s
# [BernoulliRBM] Iteration 7, pseudo-likelihood = -497.18, time = 19.09s
# [BernoulliRBM] Iteration 8, pseudo-likelihood = -496.93, time = 18.95s
# [BernoulliRBM] Iteration 9, pseudo-likelihood = -502.01, time = 18.76s
# [BernoulliRBM] Iteration 10, pseudo-likelihood = -495.84, time = 18.91s
# Pipeline(memory=None,
#      steps=[('rbm', BernoulliRBM(batch_size=10, learning_rate=0.05, n_components=256, n_iter=10,
#        random_state=None, verbose=True)), ('svc', SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto', kernel='rbf',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False))])

# %%
print("Random forest classifier using RBM features:\n%s\n" % (
    metrics.classification_report(
        Y_test,
        svc_classifier.predict(X_test))))
# Out:
# Random forest classifier using RBM features:
#              precision    recall  f1-score   support
#
#           0       0.12      0.00      0.01       331
#           1       0.00      0.00      0.00       432
#           2       0.87      0.31      0.45       310
#           3       0.00      0.00      0.00       245
#           4       0.00      0.00      0.00       498
#           5       0.00      0.01      0.01       247
#           6       0.33      0.59      0.43       348
#           7       0.33      0.00      0.01       436
#           8       0.89      0.06      0.10       288
#          10       0.46      0.13      0.20       331
#          11       0.13      0.74      0.23       209
#          12       0.00      0.00      0.00       394
#          13       0.00      0.00      0.00       291
#          14       0.29      0.07      0.11       246
#          15       1.00      0.05      0.10       347
#          16       0.96      0.16      0.27       164
#          17       0.02      0.72      0.04       144
#          18       0.00      0.00      0.00       246
#          19       0.00      0.00      0.00       248
#          20       1.00      0.03      0.05       266
#          21       0.00      0.00      0.00       346
#          22       0.00      0.00      0.00       206
#          23       0.62      0.02      0.04       267
#          24       0.00      0.00      0.00       332
#
# avg / total       0.28      0.10      0.08      7172
# /home/brandoncsteed/.local/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)

# %%
svc_classifier.score(X_test, Y_test)
# Out:
# 0.09662576687116564

# %% [markdown]
# # Results
# Using RBM to extract features was not very successful in this case.  It did improve the accuracy of the SVM classifier, but accuracy was much lower using RBM than without it in the ridge regression mode, which was the model that performed best.  Increasing the amount of data fed into the model improves the performance of the models using RBM, but this increases hardware demands and slows the models down greatly.  I notice inconsistency with shading and positioning that make difficult to distinguish between signs.  A different strategy might get better results.
